# %%
#LOGISTIC REGRESSION
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

data = pd.read_csv(r'C:\Users\KIIT\OneDrive\Desktop\logistic_regression_dataset.csv')

X = data[['Age', 'Income']]
y = data['Buy']

X_train, X_test, y_train,  y_test = train_test_split(X,y,test_size = 0.25, random_state = 0)

model = LogisticRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print('Accuracy:', accuracy_score(y_test, predictions))
print('\n Confusion Matrix:\n', confusion_matrix(y_test, predictions))
print('\n Classification Report:\n', classification_report(y_test, predictions))


import seaborn as sns

# Compute confusion matrix
cm = confusion_matrix(y_test, predictions)

# Plot confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Buy', 'Buy'], yticklabels=['No Buy', 'Buy'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()




plt.scatter(data['Age'],data['Income'], c= data['Buy'], cmap = 'coolwarm', edgecolor = 'k', label = 'Data Points')
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Logistic Regression Decision Boundary')
plt.legend()
plt.show()
# Out:
# Accuracy: 0.5
#
#  Confusion Matrix:
#  [[4 1]
#  [3 0]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         8
#    macro avg       0.29      0.40      0.33         8
# weighted avg       0.36      0.50      0.42         8

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load dataset
data = pd.read_csv(r'C:\Users\KIIT\OneDrive\Desktop\logistic_regression_dataset.csv')

# Features and target
X = data[['Age', 'Income']]
y = data['Buy']

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# Train logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predictions
predictions = model.predict(X_test)

# Model evaluation
print('Accuracy:', accuracy_score(y_test, predictions))
print('\nConfusion Matrix:\n', confusion_matrix(y_test, predictions))
print('\nClassification Report:\n', classification_report(y_test, predictions))

import seaborn as sns

# Compute confusion matrix
cm = confusion_matrix(y_test, predictions)

# Plot confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Buy', 'Buy'], yticklabels=['No Buy', 'Buy'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()


# Visualization
plt.figure(figsize=(8,6))
plt.scatter(data['Age'], data['Income'], c=data['Buy'], cmap='coolwarm', edgecolor='k', label='Data Points')


# Reshape to match the meshgrid shape
probabilities = probabilities.reshape(age_grid.shape)

# Contour plot for decision boundary
plt.contour(age_grid, income_grid, probabilities, levels=[0.5], colors='black', linestyles='dashed', linewidths=2, label='Decision Boundary')

# Sigmoid curve visualization (1D projection)
sigmoid_x = np.linspace(-6, 6, 100)  # Input values
sigmoid_y = 1 / (1 + np.exp(-sigmoid_x))  # Sigmoid function

plt.plot(sigmoid_x * 10 + data['Age'].mean(), sigmoid_y * (data['Income'].max() - data['Income'].min()) + data['Income'].min(), 
         color='green', linewidth=2, label='Sigmoid Curve')

plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Logistic Regression Decision Boundary & Sigmoid Curve')
plt.legend()
plt.show()
# Out:
# Accuracy: 0.5
#
# Confusion Matrix:
#  [[4 1]
#  [3 0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.00      0.00      0.00         3
#
#     accuracy                           0.50         8
#    macro avg       0.29      0.40      0.33         8
# weighted avg       0.36      0.50      0.42         8
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_9976\185668160.py:53: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(age_grid, income_grid, probabilities, levels=[0.5], colors='black', linestyles='dashed', linewidths=2, label='Decision Boundary')
